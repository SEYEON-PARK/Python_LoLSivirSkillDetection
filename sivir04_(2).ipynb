# %%
conda install pytorch torchvision -c pytorch
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0f84acae4106> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('conda', 'install pytorch torchvision -c pytorch')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-100> in conda(self, line)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/packaging.py in conda(self, line)
#      84         """
#      85         if not _is_conda_environment():
# ---> 86             raise ValueError("The python kernel does not appear to be a conda environment.  "
#      87                              "Please use ``%pip install`` instead.")
#      88
#
# ValueError: The python kernel does not appear to be a conda environment.  Please use ``%pip install`` instead.

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/newbest300.pt')  # local model
filepath = '/content/drive/MyDrive/교수님 파일01.webm'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('./result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=fps # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=fps # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            print("시비르 E 성공 시간 : ", frame_index/fps)


        f-=1 # f를 1 감소시키기기
      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=fps
        count_bad+=1
        use=False
  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-25e414940024> in <cell line: 3>()
#       1 # import the opencv library
#       2 import cv2
# ----> 3 import torch # 토치 추가
#       4 import numpy as np
#       5 import time
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#     455     raise  # If __file__ is not None the cause is unknown, so just re-raise.
#     456
# --> 457 for name in dir(_C):
#     458     if name[0] != '_' and not name.endswith('Base'):
#     459         __all__.append(name)
#
# NameError: name '_C' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/best.pt')  # local model
filepath = '/content/drive/MyDrive/5.KR-6475988728(u12s9).mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/5.KR-6475988728(u12s9)_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=fps # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=fps # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)


        f-=1 # f를 1 감소시키기기
      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=fps
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-5-4 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# YOLOv5s summary: 157 layers, 7088338 parameters, 0 gradients
# Adding AutoShape...
# 시비르 E 발동 시간 :  140.64360102168078
# 시비르 E 성공 시간 :  143.40072460913726
# 시비르 E 발동 시간 :  143.49161879333911
# 시비르 E 성공 시간 :  143.7643013459447
# 시비르 E 발동 시간 :  144.12787808275215
# 시비르 E 성공 시간 :  144.218772266954
# 시비르 E 발동 시간 :  144.30966645115586
# 시비르 E 성공 시간 :  144.4914548195596
# 시비르 E 발동 시간 :  144.67324318796332
# 시비르 E 성공 시간 :  144.7944354335658
# 시비르 E 발동 시간 :  145.00652186337015
# 시비르 E 성공 시간 :  145.30950247737636
# 시비르 E 발동 시간 :  145.37009860017758
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-897cdcef9ee4> in <cell line: 36>()
#      44
#      45   results=model(frame) # 만든 모델로 frame 분석!
# ---> 46   for i in range(len(results.pandas().xyxy[0].xmin)):
#      47     if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
#      48       frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in pandas(self)
#     811         for k, c in zip(['xyxy', 'xyxyn', 'xywh', 'xywhn'], [ca, ca, cb, cb]):
#     812             a = [[x[:5] + [int(x[5]), self.names[int(x[5])]] for x in x.tolist()] for x in getattr(self, k)]  # update
# --> 813             setattr(new, k, [pd.DataFrame(x, columns=c) for x in a])
#     814         return new
#     815
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in <listcomp>(.0)
#     811         for k, c in zip(['xyxy', 'xyxyn', 'xywh', 'xywhn'], [ca, ca, cb, cb]):
#     812             a = [[x[:5] + [int(x[5]), self.names[int(x[5])]] for x in x.tolist()] for x in getattr(self, k)]  # update
# --> 813             setattr(new, k, [pd.DataFrame(x, columns=c) for x in a])
#     814         return new
#     815
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     769                     )
#     770             else:
# --> 771                 mgr = dict_to_mgr(
#     772                     {},
#     773                     index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     441         from pandas.core.series import Series
#     442
# --> 443         arrays = Series(data, index=columns, dtype=object)
#     444         missing = arrays.isna()
#     445         if index is None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     397
#     398             if index is not None:
# --> 399                 index = ensure_index(index)
#     400
#     401             if data is None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    7331             return Index._with_infer(index_like, copy=copy, tupleize_cols=False)
#    7332     else:
# -> 7333         return Index._with_infer(index_like, copy=copy)
#    7334
#    7335
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _with_infer(cls, *args, **kwargs)
#     714         with warnings.catch_warnings():
#     715             warnings.filterwarnings("ignore", ".*the Index constructor", FutureWarning)
# --> 716             result = cls(*args, **kwargs)
#     717
#     718         if result.dtype == _dtype_obj and not result._is_multi:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     570                 )
#     571                 dtype = subarr.dtype
# --> 572             return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#     573
#     574     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     444         from pandas.core.indexes.range import RangeIndex
#     445
# --> 446         name = maybe_extract_name(name, data, cls)
#     447
#     448         if dtype is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in maybe_extract_name(name, obj, cls)
#    7370
#    7371
# -> 7372 def maybe_extract_name(name, obj, cls) -> Hashable:
#    7373     """
#    7374     If no name is passed, then extract it from data, validating hashability.
#
# KeyboardInterrupt:

# %% [markdown]
# KR-6476136702(U8S6)

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-eb42ca6e4af3> in <cell line: 1>()
# ----> 1 import torch
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#     455     raise  # If __file__ is not None the cause is unknown, so just re-raise.
#     456
# --> 457 for name in dir(_C):
#     458     if name[0] != '_' and not name.endswith('Base'):
#     459         __all__.append(name)
#
# NameError: name '_C' is not defined

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/newbest300.pt')  # local model
filepath = '/content/drive/MyDrive/sivir_video/KR-6476136702(U8S6).webm'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/sivir_video/KR-6476136702(U8S6)_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c0bc62e60913> in <cell line: 3>()
#       1 # import the opencv library
#       2 import cv2
# ----> 3 import torch # 토치 추가
#       4 import numpy as np
#       5 import time
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#     455     raise  # If __file__ is not None the cause is unknown, so just re-raise.
#     456
# --> 457 for name in dir(_C):
#     458     if name[0] != '_' and not name.endswith('Base'):
#     459         __all__.append(name)
#
# NameError: name '_C' is not defined

# %% [markdown]
# 5.KR-6475988728(u12s9)

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/best.pt')  # local model
filepath = '/content/drive/MyDrive/5.KR-6475988728(u12s9).mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/5.KR-6475988728(u12s9)_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###	frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-5-4 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7088338 parameters, 0 gradients
# Adding AutoShape...
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# 시비르 E 발동 시간 :  140.64360102168078
# 시비르 E 성공 시간 :  143.40072460913726
# 시비르 E 발동 시간 :  143.49161879333911
# 시비르 E 성공 시간 :  143.7643013459447
# 시비르 E 발동 시간 :  144.12787808275215
# 시비르 E 성공 시간 :  144.218772266954
# 시비르 E 발동 시간 :  144.30966645115586
# 시비르 E 실패 시간 :  664.2849962086065
# 시비르 E 발동 시간 :  664.315294270007
# 시비르 E 실패 시간 :  670.1325220589262
# 시비르 E 발동 시간 :  670.6475891027368
# 시비르 E 성공 시간 :  675.4043847426342
# 시비르 E 발동 시간 :  675.4043847426342
# 시비르 E 성공 시간 :  676.0103459706467
# 시비르 E 발동 시간 :  676.1012401548485
# 시비르 E 실패 시간 :  676.9192878126652
# 시비르 E 발동 시간 :  677.1313742424695
# 시비르 E 성공 시간 :  677.3131626108733
# 시비르 E 발동 시간 :  677.4343548564758
# 시비르 E 실패 시간 :  677.7979315932832
# 시비르 E 발동 시간 :  677.9191238388858
# 시비르 E 성공 시간 :  678.0403160844882
# 시비르 E 발동 시간 :  678.2524025142925
# 시비르 E 실패 시간 :  678.858363742305
# 시비르 E 발동 시간 :  685.4633411276402
# 시비르 E 실패 시간 :  692.825770047991
# 시비르 E 발동 시간 :  692.8560681093917
# 시비르 E 실패 시간 :  698.7641900825126
# 시비르 E 발동 시간 :  699.8852183543356
# 시비르 E 성공 시간 :  700.5820737665499
# 시비르 E 발동 시간 :  700.6123718279505
# 시비르 E 실패 시간 :  701.218333055963
# 시비르 E 발동 시간 :  701.5516117313698
# 시비르 E 실패 시간 :  703.0968128628014
# 시비르 E 발동 시간 :  703.2180051084039
# 시비르 E 실패 시간 :  703.9148605206182
# 시비르 E 발동 시간 :  704.0360527662207
# 시비르 E 실패 시간 :  711.4590778093727
# 시비르 E 발동 시간 :  712.1256351601863
# 시비르 E 실패 시간 :  712.8224905724006
# 시비르 E 발동 시간 :  712.8527886338012
# 시비르 E 실패 시간 :  718.6700164227204
# 시비르 E 발동 시간 :  757.4212369541141
# 시비르 E 실패 시간 :  760.2995527871731
# 시비르 E 발동 시간 :  760.3601489099743
# 시비르 E 실패 시간 :  765.7229057778842
# 시비르 E 발동 시간 :  809.9883734841909
# 시비르 E 실패 시간 :  827.8945277719577
# 시비르 E 발동 시간 :  858.2531852953795
# 시비르 E 실패 시간 :  882.2795479860715
# 시비르 E 발동 시간 :  883.0369995210871
# 시비르 E 실패 시간 :  886.1274017839504
# 시비르 E 발동 시간 :  888.3997563889969
# 시비르 E 실패 시간 :  888.793631187205
# 시비르 E 발동 시간 :  888.8542273100062
# 시비르 E 실패 시간 :  889.2784001696149
# 시비르 E 발동 시간 :  889.3086982310156
# 시비르 E 실패 시간 :  903.639681273509
# 시비르 E 발동 시간 :  915.6983097109561
# 시비르 E 성공 시간 :  916.5163573687728
# 시비르 E 발동 시간 :  916.576953491574
# 시비르 E 실패 시간 :  923.3334211839125
# 시비르 E 발동 시간 :  1005.0472927813862
# 시비르 E 실패 시간 :  1011.4401837369171
# length : 33409
# width : 1920
# height : 1080
# fps : 33.005412022153905
# 성공 :  14
# 실패 :  50
# 성공률 :  0.21875
# 게임 시간 :  1012.2279333333333

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/best.pt')  # local model
filepath = '/content/drive/MyDrive/6.KR-6476070057(u10s5).mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/6.KR-6476070057(u10s5).mp4_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###	frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-5-4 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# YOLOv5s summary: 157 layers, 7088338 parameters, 0 gradients
# Adding AutoShape...
# 시비르 E 발동 시간 :  3.1815026296499913
# 시비르 E 실패 시간 :  23.028019033657078
# 시비르 E 발동 시간 :  57.509447534054125
# 시비르 E 실패 시간 :  59.81224943741984
# 시비르 E 발동 시간 :  59.84254946246412
# 시비르 E 실패 시간 :  61.32725068963411
# 시비르 E 발동 시간 :  61.3575507146784
# 시비르 E 발동 시간 :  1461.9156083366931
# 시비르 E 성공 시간 :  1471.2177160252888
# 시비르 E 발동 시간 :  1474.4598187050274
# 시비르 E 실패 시간 :  1476.0960200574189
# 시비르 E 발동 시간 :  1476.1869201325517
# 시비르 E 실패 시간 :  1484.5800270698187
# 시비르 E 발동 시간 :  1485.6405279463688
# 시비르 E 성공 시간 :  1487.8827297996459
# 시비르 E 발동 시간 :  1489.6401312522144
# 시비르 E 실패 시간 :  1497.1848374882416
# 시비르 E 발동 시간 :  1499.881539717183
# 시비르 E 실패 시간 :  1512.3651500354285
# 시비르 E 발동 시간 :  1512.395450060473
# 시비르 E 실패 시간 :  1540.8168735520128
# 시비르 E 발동 시간 :  1557.1788870759272
# 시비르 E 실패 시간 :  1576.055802678517
# 시비르 E 발동 시간 :  1576.0861027035612
# 시비르 E 실패 시간 :  1577.2981037053328
# 시비르 E 발동 시간 :  1593.2056168535828
# 시비르 E 실패 시간 :  1598.6293213365097
# 시비르 E 발동 시간 :  1598.7202214116428
# 시비르 E 실패 시간 :  1599.7807222881927
# 시비르 E 발동 시간 :  1599.811022313237
# 시비르 E 실패 시간 :  1601.4775236906726
# 시비르 E 발동 시간 :  1602.9016248677542
# 시비르 E 실패 시간 :  1607.7496288748398
# 시비르 E 발동 시간 :  1611.3553318551099
# 시비르 E 실패 시간 :  1613.9611340089184
# 시비르 E 발동 시간 :  1615.8094355366197
# 시비르 E 실패 시간 :  1619.8696388925541
# 시비르 E 발동 시간 :  1619.8999389175983
# 시비르 E 실패 시간 :  1622.3239409211412
# 시비르 E 발동 시간 :  1622.4754410463627
# 시비르 E 실패 시간 :  1630.5352477081426
# 시비르 E 발동 시간 :  1634.8681512894755
# 시비르 E 실패 시간 :  1648.2607623590497
# 시비르 E 발동 시간 :  1648.3819624592268
# 시비르 E 실패 시간 :  1649.9272637364854
# 시비르 E 발동 시간 :  1650.412064137194
# length : 54570
# width : 1920
# height : 1080
# fps : 33.003273051373036
# 성공 :  14
# 실패 :  164
# 성공률 :  0.07865168539325842
# 게임 시간 :  1653.4723666666669

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/lastbest.pt')  # local model
filepath = '/content/drive/MyDrive/5.KR-6475988728(u12s9).mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/5.KR-6475988728(u12s9)_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
   # by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###   frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-5-4 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# Fusing layers...
# YOLOv5s summary: 157 layers, 7088338 parameters, 0 gradients
# Adding AutoShape...
# 시비르 E 발동 시간 :  41.02357513644028
# 시비르 E 성공 시간 :  42.144603408263244
# 시비르 E 발동 시간 :  42.296093715266345
# 시비르 E 실패 시간 :  114.19339341893901
# 시비르 E 발동 시간 :  143.7340032845441
# 시비르 E 실패 시간 :  144.70354124936392
# 시비르 E 발동 시간 :  144.76413737216518
# 시비르 E 성공 시간 :  145.43069472297884
# 시비르 E 발동 시간 :  147.1273861614136
# 시비르 E 실패 시간 :  204.7240008839933
# 시비르 E 발동 시간 :  224.5389330399992
# 시비르 E 성공 시간 :  271.83420688636795
# 시비르 E 발동 시간 :  281.28720204336156
# 시비르 E 성공 시간 :  289.9221495425384
# 시비르 E 발동 시간 :  296.8301075418799
# 시비르 E 성공 시간 :  296.9210017260818
# 시비르 E 발동 시간 :  311.55496538258154
# 시비르 E 성공 시간 :  313.8273199876281
# 시비르 E 발동 시간 :  337.5204040029134
# 시비르 E 성공 시간 :  340.2169314675686
# 시비르 E 발동 시간 :  340.61080626577666
# 시비르 E 성공 시간 :  340.70170044997855
# 시비르 E 발동 시간 :  432.80780710786513
# 시비르 E 실패 시간 :  471.5590276392589
# 시비르 E 발동 시간 :  475.2856891915352
# 시비르 E 실패 시간 :  480.4363596296407
# 시비르 E 발동 시간 :  481.4361956558612
# 시비르 E 성공 시간 :  486.6474622167679
# 시비르 E 발동 시간 :  530.8220357388727
# 시비르 E 성공 시간 :  530.9735260458758
# 시비르 E 발동 시간 :  533.4579670807267
# 시비르 E 성공 시간 :  533.5791593263292
# 시비르 E 발동 시간 :  578.9050591816576
# 시비르 E 실패 시간 :  609.4152070120825
# 시비르 E 발동 시간 :  622.2918831073463
# 시비르 E 실패 시간 :  625.745862107017
# 시비르 E 발동 시간 :  634.0172328693865
# 시비르 E 성공 시간 :  635.7442223692218
# 시비르 E 발동 시간 :  675.980047909246
# 시비르 E 실패 시간 :  677.5555471020782
# 시비르 E 발동 시간 :  677.6161432248795
# 시비르 E 실패 시간 :  677.9797199616869
# 시비르 E 발동 시간 :  677.9797199616869
# 시비르 E 성공 시간 :  678.1615083300907
# 시비르 E 발동 시간 :  678.4038928212956
# 시비르 E 실패 시간 :  686.039004294252
# 시비르 E 발동 시간 :  700.4002853981461
# 시비르 E 성공 시간 :  700.5820737665499
# 시비르 E 발동 시간 :  701.7031020383729
# 시비르 E 성공 시간 :  702.8241303101959
# 시비르 E 발동 시간 :  711.9741448531832
# 시비르 E 성공 시간 :  712.7618944495994
# 시비르 E 발동 시간 :  739.302996236543
# 시비르 E 실패 시간 :  758.4513710417352
# 시비르 E 발동 시간 :  764.3897910762569
# 시비르 E 실패 시간 :  813.9271214662715
# 시비르 E 발동 시간 :  874.1293694693046
# 시비르 E 성공 시간 :  883.5823646262983
# 시비르 E 발동 시간 :  883.8247491175032
# 시비르 E 실패 시간 :  888.4603525117982
# 시비르 E 발동 시간 :  888.4906505731988
# 시비르 E 성공 시간 :  889.2481021082143
# 시비르 E 발동 시간 :  915.6377135881548
# 시비르 E 실패 시간 :  922.7880560787013
# 시비르 E 발동 시간 :  939.421691787642
# 시비르 E 실패 시간 :  979.2636425294581
# 시비르 E 발동 시간 :  979.35453671366
# 시비르 E 실패 시간 :  992.928068221138
# 시비르 E 발동 시간 :  1005.7744462550011
# length : 33409
# width : 1920
# height : 1080
# fps : 33.005412022153905
# 성공 :  18
# 실패 :  16
# 성공률 :  0.5294117647058824
# 게임 시간 :  1012.2279333333333

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/lastbest.pt')  # local model
filepath = '/content/drive/MyDrive/6.KR-6476070057(u10s5).mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/6.KR-6476070057(u10s5)_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
   # by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###   frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-5-5 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# Fusing layers...
# YOLOv5s summary: 157 layers, 7088338 parameters, 0 gradients
# Adding AutoShape...
# 시비르 E 발동 시간 :  115.5642955189054
# 시비르 E 성공 시간 :  117.80649737218253
# 시비르 E 발동 시간 :  190.16295717793662
# 시비르 E 실패 시간 :  213.46367643699227
# 시비르 E 발동 시간 :  225.28068620426365
# 시비르 E 성공 시간 :  225.4321863294851
# 시비르 E 발동 시간 :  225.4321863294851
# 시비르 E 성공 시간 :  225.91698673019366
# 시비르 E 발동 시간 :  226.0381868303708
# 시비르 E 성공 시간 :  226.73508740638937
# 시비르 E 발동 시간 :  229.09848935984365
# 시비르 E 성공 시간 :  229.82568996090652
# 시비르 E 발동 시간 :  232.76479239020222
# 시비르 E 성공 시간 :  234.52219384277078
# 시비르 E 발동 시간 :  282.4871334878749
# 시비르 E 성공 시간 :  318.241163040132
# 시비르 E 발동 시간 :  338.8451800702462
# 시비르 E 실패 시간 :  344.2991845782176
# 시비르 E 발동 시간 :  409.08063812290027
# 시비르 E 성공 시간 :  447.80407012949735
# 시비르 E 발동 시간 :  513.7369246258628
# 시비르 E 실패 시간 :  534.0379414055342
# 시비르 E 발동 시간 :  544.0672496951928
# 시비르 E 실패 시간 :  575.7913759165598
# 시비르 E 발동 시간 :  584.4874831042698
# 시비르 E 실패 시간 :  620.1809126064383
# 시비르 E 발동 시간 :  630.8465214220269
# 시비르 E 성공 시간 :  639.3002284093825
# 시비르 E 발동 시간 :  670.4789541799524
# 시비르 E 성공 시간 :  688.2953689059924
# 시비르 E 발동 시간 :  702.2939804764524
# 시비르 E 성공 시간 :  714.2624903689451
# 시비르 E 발동 시간 :  746.9259173666851
# 시비르 E 실패 시간 :  753.925223151915
# 시비르 E 발동 시간 :  762.7122304147579
# 시비르 E 성공 시간 :  777.7410428367235
# 시비르 E 발동 시간 :  798.0420596163949
# 시비르 E 성공 시간 :  798.163259716572
# 시비르 E 발동 시간 :  863.0356133363875
# 시비르 E 실패 시간 :  876.0040240553418
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1c53f76730a7> in <cell line: 40>()
#      51
#      52   results=model(frame) # 만든 모델로 frame 분석!
# ---> 53   for i in range(len(results.pandas().xyxy[0].xmin)):
#      54     if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
#      55       frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in pandas(self)
#     811         for k, c in zip(['xyxy', 'xyxyn', 'xywh', 'xywhn'], [ca, ca, cb, cb]):
#     812             a = [[x[:5] + [int(x[5]), self.names[int(x[5])]] for x in x.tolist()] for x in getattr(self, k)]  # update
# --> 813             setattr(new, k, [pd.DataFrame(x, columns=c) for x in a])
#     814         return new
#     815
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in <listcomp>(.0)
#     811         for k, c in zip(['xyxy', 'xyxyn', 'xywh', 'xywhn'], [ca, ca, cb, cb]):
#     812             a = [[x[:5] + [int(x[5]), self.names[int(x[5])]] for x in x.tolist()] for x in getattr(self, k)]  # update
# --> 813             setattr(new, k, [pd.DataFrame(x, columns=c) for x in a])
#     814         return new
#     815
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     769                     )
#     770             else:
# --> 771                 mgr = dict_to_mgr(
#     772                     {},
#     773                     index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     446             # GH10856
#     447             # raise ValueError if only scalars in dict
# --> 448             index = _extract_index(arrays[~missing])
#     449         else:
#     450             index = ensure_index(index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1003             key = check_bool_indexer(self.index, key)
#    1004             key = np.asarray(key, dtype=bool)
# -> 1005             return self._get_values(key)
#    1006
#    1007         return self._get_with(key)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_values(self, indexer)
#    1067
#    1068     def _get_values(self, indexer: slice | npt.NDArray[np.bool_]) -> Series:
# -> 1069         new_mgr = self._mgr.getitem_mgr(indexer)
#    1070         return self._constructor(new_mgr).__finalize__(self)
#    1071
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in getitem_mgr(self, indexer)
#    2029             raise ValueError("dimension-expanding indexing not allowed")
#    2030
# -> 2031         bp = BlockPlacement(slice(0, len(array)))
#    2032         block = type(blk)(array, placement=bp, ndim=1)
#    2033
#
# KeyboardInterrupt:
