# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/sivir_video/best.pt')  # local model
filepath = '/content/drive/MyDrive/sivir_video/KR-6476136702(U8S6).webm'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/KR-6476136702(U8S6)_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###	frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-5-4 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# 시비르 E 실패 시간 :  641.7166666666667
# 시비르 E 발동 시간 :  641.7333333333333
# 시비르 E 실패 시간 :  642.1666666666666
# 시비르 E 발동 시간 :  642.4166666666666
# 시비르 E 실패 시간 :  646.1333333333333
# 시비르 E 발동 시간 :  646.15
# 시비르 E 실패 시간 :  646.55
# 시비르 E 발동 시간 :  646.5666666666667
# 시비르 E 실패 시간 :  646.9666666666667
# 시비르 E 발동 시간 :  646.9833333333333
# 시비르 E 실패 시간 :  647.5166666666667
# 시비르 E 발동 시간 :  647.7333333333333
# 시비르 E 실패 시간 :  648.5666666666667
# 시비르 E 발동 시간 :  648.5833333333334
# 시비르 E 실패 시간 :  649.25
# 시비르 E 발동 시간 :  649.35
# 시비르 E 실패 시간 :  649.9666666666667
# 시비르 E 발동 시간 :  662.1166666666667
# 시비르 E 실패 시간 :  662.5166666666667
# 시비르 E 발동 시간 :  662.5333333333333
# 시비르 E 실패 시간 :  663.4
# 시비르 E 발동 시간 :  666.8833333333333
# length : 56570
# width : 1280
# height : 720
# fps : 60.0
# 성공 :  2
# 실패 :  43
# 성공률 :  0.044444444444444446
# 게임 시간 :  942.8333333333334

# %% [markdown]
# 2번

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/sivir_video/lastbest.pt')  # local model
filepath = '/content/drive/MyDrive/sivir_video/2.KR-6474155597(u12s6).mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/KR-6474155597(u12s6)_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###	frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-5-4 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7088338 parameters, 0 gradients
# Adding AutoShape...
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# 시비르 E 발동 시간 :  25.633333333333333
# 시비르 E 실패 시간 :  29.866666666666667
# 시비르 E 발동 시간 :  30.533333333333335
# 시비르 E 성공 시간 :  58.8
# 시비르 E 발동 시간 :  126.76666666666667
# 시비르 E 성공 시간 :  182.93333333333334
# 시비르 E 발동 시간 :  312.23333333333335
# 시비르 E 성공 시간 :  328.9
# 시비르 E 발동 시간 :  443.23333333333335
# 시비르 E 실패 시간 :  488.03333333333336
# 시비르 E 발동 시간 :  540.0
# 시비르 E 성공 시간 :  552.4
# 시비르 E 발동 시간 :  606.8
# 시비르 E 실패 시간 :  607.6666666666666
# 시비르 E 발동 시간 :  607.7333333333333
# 시비르 E 실패 시간 :  608.5666666666667
# 시비르 E 발동 시간 :  608.6
# 시비르 E 실패 시간 :  626.6666666666666
# 시비르 E 발동 시간 :  638.0
# 시비르 E 실패 시간 :  641.4333333333333
# 시비르 E 발동 시간 :  863.0666666666667
# 시비르 E 실패 시간 :  868.0333333333333
# 시비르 E 발동 시간 :  876.2666666666667
# 시비르 E 성공 시간 :  885.6333333333333
# 시비르 E 발동 시간 :  893.1
# 시비르 E 실패 시간 :  929.4
# 시비르 E 발동 시간 :  968.4666666666667
# 시비르 E 성공 시간 :  991.5
# 시비르 E 발동 시간 :  993.8666666666667
# 시비르 E 성공 시간 :  994.6666666666666
# 시비르 E 발동 시간 :  995.1
# 시비르 E 성공 시간 :  996.5333333333333
# 시비르 E 발동 시간 :  996.9333333333333
# 시비르 E 성공 시간 :  1009.4666666666667
# 시비르 E 발동 시간 :  1012.3
# 시비르 E 성공 시간 :  1012.5333333333333
# 시비르 E 발동 시간 :  1012.9333333333333
# 시비르 E 성공 시간 :  1013.3
# length : 34203
# width : 1268
# height : 756
# fps : 30.0
# 성공 :  11
# 실패 :  8
# 성공률 :  0.5789473684210527
# 게임 시간 :  1140.1

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/sivir_video/lastbest.pt')  # local model
filepath = '/content/drive/MyDrive/sivir_video/008.mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/08_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###	frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f6fff2a73669> in <cell line: 40>()
#      50   # frame=im_trim(image, 680,326,1454,756)
#      51
# ---> 52   results=model(frame) # 만든 모델로 frame 분석!
#      53   for i in range(len(results.pandas().xyxy[0].xmin)):
#      54     if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in forward(self, ims, size, augment, profile)
#     703             # Inference
#     704             with dt[1]:
# --> 705                 y = self.model(x, augment=augment)  # forward
#     706
#     707             # Post-process
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in forward(self, im, augment, visualize)
#     513
#     514         if self.pt:  # PyTorch
# --> 515             y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     516         elif self.jit:  # TorchScript
#     517             y = self.model(im)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/yolo.py in forward(self, x, augment, profile, visualize)
#     207         if augment:
#     208             return self._forward_augment(x)  # augmented inference, None
# --> 209         return self._forward_once(x, profile, visualize)  # single-scale inference, train
#     210
#     211     def _forward_augment(self, x):
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/yolo.py in _forward_once(self, x, profile, visualize)
#     119             if profile:
#     120                 self._profile_one_layer(m, x, dt)
# --> 121             x = m(x)  # run
#     122             y.append(x if m.i in self.save else None)  # save output
#     123             if visualize:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in forward(self, x)
#     165
#     166     def forward(self, x):
# --> 167         return self.cv3(torch.cat((self.m(self.cv1(x)), self.cv2(x)), 1))
#     168
#     169
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py in forward_fuse(self, x)
#      57
#      58     def forward_fuse(self, x):
# ---> 59         return self.act(self.conv(x))
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     457                             weight, bias, self.stride,
#     458                             _pair(0), self.dilation, self.groups)
# --> 459         return F.conv2d(input, weight, bias, self.stride,
#     460                         self.padding, self.dilation, self.groups)
#     461
#
# KeyboardInterrupt:

# %% [markdown]
# 9번

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/sivir_video/lastbest.pt')  # local model
filepath = '/content/drive/MyDrive/sivir_video/KR-6476136702(U8S6).webm'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/09_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###	frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-5-5 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# Fusing layers...
# YOLOv5s summary: 157 layers, 7088338 parameters, 0 gradients
# Adding AutoShape...
# 시비르 E 발동 시간 :  88.9
# 시비르 E 성공 시간 :  88.95
# 시비르 E 발동 시간 :  89.66666666666667
# 시비르 E 성공 시간 :  92.68333333333334
# 시비르 E 발동 시간 :  160.31666666666666
# 시비르 E 성공 시간 :  160.61666666666667
# 시비르 E 발동 시간 :  268.95
# 시비르 E 성공 시간 :  321.85
# 시비르 E 발동 시간 :  333.8
# 시비르 E 실패 시간 :  336.35
# 시비르 E 발동 시간 :  398.81666666666666
# 시비르 E 실패 시간 :  404.93333333333334
# 시비르 E 발동 시간 :  479.8833333333333
# 시비르 E 실패 시간 :  480.7
# 시비르 E 발동 시간 :  480.9166666666667
# 시비르 E 실패 시간 :  508.71666666666664
# 시비르 E 발동 시간 :  509.95
# 시비르 E 실패 시간 :  511.53333333333336
# 시비르 E 발동 시간 :  511.55
# 시비르 E 성공 시간 :  512.0333333333333
# 시비르 E 발동 시간 :  512.3166666666667
# 시비르 E 실패 시간 :  518.6666666666666
# 시비르 E 발동 시간 :  599.5833333333334
# 시비르 E 실패 시간 :  600.6833333333333
# 시비르 E 발동 시간 :  600.9333333333333
# 시비르 E 성공 시간 :  600.9666666666667
# 시비르 E 발동 시간 :  639.3333333333334
# 시비르 E 성공 시간 :  640.95
# 시비르 E 발동 시간 :  660.9833333333333
# 시비르 E 성공 시간 :  661.2166666666667
# length : 56570
# width : 1280
# height : 720
# fps : 60.0
# 성공 :  8
# 실패 :  7
# 성공률 :  0.5333333333333333
# 게임 시간 :  942.8333333333334

# %% [markdown]
# 6번

# %%
# import the opencv library
import cv2
import torch # 토치 추가
import numpy as np
import time

# define a video capture object

model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/sivir_video/lastbest.pt')  # local model
filepath = '/content/drive/MyDrive/sivir_video/6.KR-6476070057(u10s5).mp4'
video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함

if not video.isOpened():
    print("Could not Open :", filepath)
    exit(0)

#불러온 비디오 파일의 정보 출력
length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = video.get(cv2.CAP_PROP_FPS)

fourcc=cv2.VideoWriter_fourcc('m', 'p', '4', 'v')
writer=cv2.VideoWriter('/content/drive/MyDrive/06_result.mp4', fourcc, fps, (width, height))

blue_color=(255,0,0)
other_color=(0, 0, 255)
use=False # e 스킬 사용했는지 확인!
sucess=False # e 스킬 성공했는지 확인!
f=24 # 60 프레임 보겠다!
count_good=0 # 성공 횟수!
count_bad=0 # 실패 횟수!
count_frame=0 # 3번 동안 성공 유지했는지 보겠다!
frame_index=0

#def im_trim(img, x, y, w, h):
#    imgtrim = img[y: y + h, x: x + w]
#    return imgtrim

while(video.isOpened() and frame_index<length): #
  frame_index+=1
  #print("start time : ", time.time())
    # Capture the video frame
	# by frame
  ret, frame = video.read()
  if(type(frame)==type(None)):
    continue
###	frame=frame[:240,0:320]

  # frame=im_trim(image, 680,326,1454,756)

  results=model(frame) # 만든 모델로 frame 분석!
  for i in range(len(results.pandas().xyxy[0].xmin)):
    if(results.pandas().xyxy[0].name[i]=="1" and results.pandas().xyxy[0].confidence[i]>=0.7): # 스킬 발동했다면
      frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), blue_color, 3)
      cv2.putText(frame, "use "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
      if(use==False):
          print("시비르 E 발동 시간 : ", frame_index/fps)
          use=True # use를 True로 변경!

    if(use==True): # 만약, use가 True라면
      if(f>0): # f(프레임수)가 0보다 크다면
        f-=1 # f를 1 감소시키기기
        if(results.pandas().xyxy[0].name[i]=="0" and results.pandas().xyxy[0].confidence[i]>=0.7): # 만약, 성공했다면
          count_frame+=1 # 성공 프레임 1 증가하기
          if(count_frame>=3): # 성공 프레임이 3개라면
            frame=cv2.rectangle(frame, (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), (int(results.pandas().xyxy[0].xmax[i]), int(results.pandas().xyxy[0].ymax[i])), other_color, 3)
            cv2.putText(frame, "success "+str(results.pandas().xyxy[0].confidence[i]), (int(results.pandas().xyxy[0].xmin[i]), int(results.pandas().xyxy[0].ymin[i])), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36,255,12), 2)
            count_good+=1 # 성공 횟수 1 증가시키기
            f=24 # 프레임 세는 것도 초기화하기
            use=False # use를 False로 바꾸기
            count_frame=0
            print("시비르 E 성공 시간 : ", frame_index/fps)

      else:
        print("시비르 E 실패 시간 : ", frame_index/fps)
        f=24
        count_bad+=1
        use=False
        count_frame=0

  writer.write(frame)

# After the loop release the cap object
video.release()
writer.release()

print("length :", length)
print("width :", width)
print("height :", height)
print("fps :", fps)
print("성공 : ", count_good)
print("실패 : ", count_bad)
print("성공률 : ", count_good/(count_good+count_bad))
print("게임 시간 : ", length/fps)


# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-5-5 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
